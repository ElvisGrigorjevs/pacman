# %% [markdown]
# <a href="https://colab.research.google.com/github/ElvisGrigorjevs/pacman/blob/main/prog1_pokemoni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pokemon_df = pd.read_csv('/content/Pokemon.csv')
pokemon_df.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
unikalie_tipi = pokemon_df['Type 1'].nunique()
print(unikalie_tipi)
# Out:
# 18

# %%
defense_100 = pokemon_df[pokemon_df['Defense'] > 100] # dataframe ar filtru
skaits = defense_100['Name'].count()
print(skaits)
# Out:
# 123

# %%
defense_attack_100 = defense_100[defense_100['Attack'] > 100]
defense_attack_100
# Out:
#        #                       Name   Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire    Dragon    634   78     130
# 12     9    BlastoiseMega Blastoise    Water       NaN    630   79     103
# 82    76                      Golem     Rock    Ground    495   80     120
# 107   99                    Kingler    Water       NaN    475   55     130
# 120  112                     Rhydon   Ground      Rock    485  105     130
# 137  127          PinsirMega Pinsir      Bug    Flying    600   65     155
# 141  130      GyaradosMega Gyarados    Water      Dark    640   95     155
# 152  141                   Kabutops     Rock     Water    495   60     115
# 224  208        SteelixMega Steelix    Steel    Ground    610   75     125
# 229  212          ScizorMega Scizor      Bug     Steel    600   70     150
# 232  214    HeracrossMega Heracross      Bug  Fighting    600   80     185
# ...

# %%
defense_attack_100 = pokemon_df[(pokemon_df['Defense'] > 100) & (pokemon_df['Attack'] > 100)]
defense_attack_100.head()
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 12     9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# 82    76                      Golem    Rock  Ground    495   80     120
# 107   99                    Kingler   Water     NaN    475   55     130
# 120  112                     Rhydon  Ground    Rock    485  105     130
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 12       120      135      115     78           1      False
# 82       130       55       65     45           1      False
# 107      115       50       50     75           1      False
# 120      120       45       45     40           1      False
